# %%
import numpy as np
from tqdm import tqdm
from scipy import signal
from pathlib import Path
from utils.plot_utils import *
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from sympy import Symbol, zeros, Function, MatrixSymbol

# %% [markdown]
# Looking for a fast way to solve the following differential equation:
#
# $\frac{𝜕𝜌}{𝑑𝑡}=−\frac{𝑖}{ℏ} [𝐻(𝑡),𝜌]+∑_k 𝐶_𝑘 𝜌𝐶_𝑘^\dagger-\frac{1}{2}∑_𝑘(𝐶_𝑘  𝐶_𝑘^\dagger 𝜌+𝜌𝐶_𝑘^\dagger 𝐶_𝑘 ) $
#
# ## Defining some constants
#
# These are used for setting up the OBE system for TlF

# %%
de_main = -0.39444661382277774 # main dipole transition moment

Γ = 1/(100e-9)
Ω =  1*Γ
ωp = Γ
νp = ωp/(2*np.pi)

# microwaves
Ω1 = 1*Γ
νp1 = ωp/(2*np.pi)

Ω2 = 1*Γ
νp2 = ωp/(2*np.pi)

# 'state' indices of the Hamiltonian arrays for the ground and excited state 
# respectively, which is the main state the laser couples
ground_main_idx = 26
excited_main_idx = 9

# %% [markdown]
# ## Loading matrices used in OBE system
#
# These matrices are for a 39x39 TlF system, $X,~J=0\rightarrow2;~B,~J=1$ with a laser on $X,~J=2 \rightarrow B,~J=1$
# The X is the ground state, B the excited state.
# `H_laser` are the lightfield Hamiltonians, here for x and z polarization.
# `C_array` contains the collapse operators $C_k$
# `ρ_ini` gives the initial distribution, in this case for TlF @7 K

# %%
data_dir = Path('stored_data')

fnames = ['H_laser_x', 'H_laser_z', 'H_X_red', 'H_B_red', 'H_B_diag', 'C_array', 'rho_ini', 
          'D1', 'D2', 'H_mu1_y', 'H_mu1_z', 'H_mu2_y', 'H_mu2_z']

for fname in fnames:
    if fname == 'rho_ini':
        ρ_ini = np.load(data_dir / (fname + '.npy'))
    else:
        globals()[fname] = np.load(data_dir / (fname + '.npy'))
        
C_conj_array = np.einsum('ijk->ikj', C_array.conj())

_ = np.zeros(H_laser_x.shape, dtype = 'complex')
_[:64,:64] = H_mu1_z[:64,:64]
H_mu1_z = _.copy()

_ = np.zeros(H_laser_x.shape, dtype = 'complex')
_[:64,:64] = H_mu1_y[:64,:64]
H_mu1_y = _.copy()

_ = np.zeros(H_laser_x.shape, dtype = 'complex')
_[:64,:64] = H_mu2_z[:64,:64]
H_mu2_z = _.copy()

_ = np.zeros(H_laser_x.shape, dtype = 'complex')
_[:64,:64] = H_mu2_y[:64,:64]
H_mu2_y = _.copy()

# %% [markdown]
# ## Hamiltonian
# ### Time independent part

# %%
# shifting the X Hamiltonian such that the main ground level is set to zero
H_X_rot = H_X_red + D1 + D2
H_X_shifted = H_X_rot - H_X_rot[ground_main_idx,ground_main_idx]*np.eye(H_X_rot.shape[0])

# shifting the Y Hamiltonian such that the main excited level is set to zero
Δ = 0
H_B_shifted = np.diag(np.diag(H_B_red - H_B_diag[excited_main_idx,excited_main_idx] + Δ))

# creating a single array with both the X and B Hamiltonians
_H = np.zeros(H_laser_x.shape, dtype = 'complex')
_H[:64, :64] = H_X_shifted
_H[64:,64:] = H_B_shifted

# %% [markdown]
# ### Time dependent part

# %%
# defining a square wave function, used for polarization switching

def square_wave(t, frequency, phase = 0):
    return 0.5*(1+signal.square(2*np.pi*frequency*t+phase))

# %%
ϕlaser = 0
ϕμ1 = np.pi/3
ϕμ2 = 2*np.pi/3
# defining a function for the time dependent part of the Hamiltonian
H_oc_t = lambda t, Ω, νp: (Ω/de_main)/2*(H_laser_z*square_wave(t, νp, ϕlaser) + H_laser_x*square_wave(t, νp, ϕlaser + np.pi))
H_mu1_t = lambda t, Ω, νp: Ω * (H_mu1_y * square_wave(t, νp, ϕμ1) + H_mu1_z * square_wave(t, νp, ϕμ1 + np.pi))
H_mu2_t = lambda t, Ω, νp: Ω * (H_mu2_y * square_wave(t, νp, ϕμ2) + H_mu2_z * square_wave(t, νp, ϕμ2 + np.pi))

# adding the time dependent and independent parts
def Hamiltonian(t, Ω, νp, Ω1, νp1, Ω2, νp2):
    return _H + H_oc_t(t, Ω, νp) + H_mu1_t(t, Ω1, νp1) + H_mu2_t(t, Ω2, νp2)

# %% [markdown]
# ## Setting up the Lindblad Equation
# $\frac{𝜕𝜌}{𝑑𝑡}=−\frac{𝑖}{ℏ} [𝐻(𝑡),𝜌]+∑_k 𝐶_𝑘 𝜌𝐶_𝑘^\dagger-\frac{1}{2}∑_𝑘(𝐶_𝑘  𝐶_𝑘^\dagger 𝜌+𝜌𝐶_𝑘^\dagger 𝐶_𝑘 ) $
#
# Below calculate $L$ such that $∑_k 𝐶_𝑘 𝜌𝐶_𝑘^\dagger$ can be written as $L\cdot{\rm flat}(\rho)$ (courtesy of Oskari).

# %%
from scipy.sparse import kron, csr_matrix

L_collapse = np.zeros((C_array.shape[1]**2,C_array.shape[1]**2), dtype = complex)
identity = np.eye(C_array.shape[1],C_array.shape[2])
for C in tqdm(C_array):
    L_collapse += (kron(C.conj(), C)
                    -1/2 * (kron(identity, C.conj().T @ C) + 
                            kron(C.conj().T @ C, identity)))
    
# Make the collapse operator into a sparse matrix
L_collapse = csr_matrix(L_collapse)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 33/33 [00:02<00:00, 12.14it/s]

# %%
C_array.shape
# Out:
# (33, 67, 67)

# %%
# calculates the RHS of the Lindblad equation
# use numpy array operations as much as possible, this calls BLAS
# and numpy with MKL (Intel Math Kernel Library) this vectorizes
# common array operations over the CPU, using multiple cores

def Lindblad_rhs(t, rho_vec, p):
    dim = int(np.sqrt(len(rho_vec)))
    rho = rho_vec.reshape((dim,dim))
    
    Ham = Hamiltonian(t, *p)

    rhs_H = (-1j* (Ham @ rho - rho @ Ham)).flatten()
    rhs_C = L_collapse @ rho_vec
    rhs = rhs_H + rhs_C
    return rhs

# %% [markdown]
# ## Using Scipy to solve
# With solve_ivp the default solver is `RK45`, but I explicitly call the method here for clarity.

# %%
t_span = (0, 100e-6)
ρ_vec = ρ_ini.flatten() # flatten the initial conditions, can't pass 2D array to the ODE solver
p = [Ω, νp, Ω1, νp1, Ω2, νp2] # parameters to pass to function
# p = [Ω, νp, 0, 0, 0, 0] # parameters to pass to function

# %%
# %%timeit
# with MKL this utilizes multiple cores to do the array operations
# essentially splitting them over the cores
sol = solve_ivp(Lindblad_rhs, t_span, ρ_vec, method = 'RK45', dense_output=False, 
                vectorized = False, args = [p], rtol = 2.5e-4, atol = 2.5e-7)
# Out:
# 13.9 s ± 595 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%time
sol = solve_ivp(Lindblad_rhs, t_span, ρ_vec, method = 'RK45', dense_output=False, 
                vectorized = False, args = [p], rtol = 2.5e-4, atol = 2.5e-7)

pop_results = np.real(np.einsum('jji->ji',sol.y.reshape((ρ_ini.shape[0], ρ_ini.shape[1], sol.y.shape[1]))))

t_array = sol.t

m = t_array <= 300e-6

t_array = t_array[m]
pop_results = pop_results[:,m]

#Plot populations in different J
P0_triplet = np.sum(pop_results[1:4,:], axis = 0)
P0_singlet = np.sum(pop_results[0:1,:], axis = 0)
P0 = np.sum(pop_results[:4], axis = 0)
P1 = np.sum(pop_results[4:16,:], axis = 0)
P2 = np.sum(pop_results[16:36,:], axis = 0)
P3 = np.sum(pop_results[36:64,:], axis = 0)
PB1 = np.sum(pop_results[64:,:], axis = 0)

fig, ax = plt.subplots(figsize = (12,8))
ax.plot(t_array*1e6, P0, label = 'X, J = 0')
ax.plot(t_array*1e6, P1, label = 'X, J = 1')
ax.plot(t_array*1e6, P2, label = 'X, J = 2')
ax.plot(t_array*1e6, PB1, label = 'B, J = 1')
ax.legend(fontsize = 14)
ax.set_xlabel("Time [us]", fontsize = 14)
ax.set_ylabel("Population in state", fontsize = 14)
ax.tick_params(axis='both', labelsize=14)
ax.grid(True)

fig, ax = plt.subplots(figsize = (12,8))
ax.plot(t_array*1e6, P0, label = 'X, J = 0')
ax.plot(t_array*1e6, P1, label = 'X, J = 1')
ax.plot(t_array*1e6, P2, label = 'X, J = 2')
ax.plot(t_array*1e6, PB1, label = 'B, J = 1 ')
ax.legend(fontsize = 14)
ax.set_xlabel("Time [us]", fontsize = 14)
ax.set_ylabel("Population in state", fontsize = 14)
ax.tick_params(axis='both', labelsize=14)
ax.set_xlim(0,5e6/νp)
for i in range(20):
    ax.axvline(i*1e6/νp/2, zorder = 0, color = 'k')
    
print(f"{P0[-1]/P0[0]:.3f} J0 ratio")
# Out:
# 15.437 J0 ratio
# Wall time: 12.4 s

# %% [markdown]
# ## Converting to symbolic for pre-calculation
# Defining constants and functions as symbols

# %%
t = Symbol("t", real = True)
Ω = Symbol("Ω", complex = True)
Ωᶜ = Symbol("Ωᶜ", complex = True) # complex conjuage of Ω
Ω1 = Symbol("Ω1", complex = True)
Ω1ᶜ = Symbol("Ω1ᶜ", complex = True)
Ω2 = Symbol("Ω2", complex = True)
Ω2ᶜ = Symbol("Ω2ᶜ", complex = True)
Δ = Symbol("Δ", real = True)

Plx = Function("Plx")(t) # Polarization switching function for laser x
Plz = Function("Plz")(t) # Polarization switching function for laser z

Pμ1y = Function("Pμ1y")(t) # Polarization switching function for microwave y
Pμ1z = Function("Pμ1z")(t) # Polarization switching function for microwave z

Pμ2y = Function("Pμ2y")(t) # Polarization switching function for microwave y
Pμ2z = Function("Pμ2z")(t) # Polarization switching function for microwave z

# %% [markdown]
# ## Creating a symbolic density matrix
# Used to do the symbolic matrix multiplication, so that we can auto-generate code that is essentially the operations of the RHS of the Lindblad equation written out line-by-line for each matrix element of the LHS.

# %%
def recursive_subscript(i):
    # chr(0x2080+i) is unicode for
    # subscript num(i), resulting in x₀₀ for example
    if i < 10:
        return chr(0x2080+i)
    else:
        return recursive_subscript(i//10)+chr(0x2080+i%10)

# %%
ρ = zeros(*ρ_ini.shape)
levels = ρ_ini.shape[0]
for i in range(levels):
    for j in range(i,levels):
        # \u03C1 is unicode for ρ, 
        if i == j:
            ρ[i,j] = Symbol(u'\u03C1{0},{1}'. \
            format(recursive_subscript(i), recursive_subscript(j)))
        else:
            ρ[i,j] = Symbol(u'\u03C1{0},{1}'. \
            format(recursive_subscript(i), recursive_subscript(j)))
            ρ[j,i] = Symbol(u'\u03C1{1},{0}'. \
            format(recursive_subscript(i), recursive_subscript(j)))

# %%
ρ[:4,:4]
# Out:
# Matrix([
# [ρ₀,₀, ρ₀,₁, ρ₀,₂, ρ₀,₃],
# [ρ₁,₀, ρ₁,₁, ρ₁,₂, ρ₁,₃],
# [ρ₂,₀, ρ₂,₁, ρ₂,₂, ρ₂,₃],
# [ρ₃,₀, ρ₃,₁, ρ₃,₂, ρ₃,₃]])

# %% [markdown]
# ## Setting up the Hamiltonian with symbolic variables and functions

# %%
# setup the Hamiltonian, with time dependent functions for the laser polarization
Ham = zeros(*ρ_ini.shape)
Ham += ((Ω/de_main)/2)*(H_laser_z*Plz + H_laser_x*Plx) + Ω1*(H_mu1_y*Pμ1y + H_mu1_z*Pμ1z) + Ω2*(H_mu2_y*Pμ2y + H_mu2_z*Pμ2z)
Ham += _H

# %%
# ensure Hermitian Hamiltonian for complex Ω
for idx in range(Ham.shape[0]):
    for idy in range(Ham.shape[0]):
        if idx > idy:
            Ham[idx,idy] = Ham[idx,idy].subs(Ω, Ωᶜ)
            Ham[idx,idy] = Ham[idx,idy].subs(Ω1, Ω1ᶜ)
            Ham[idx,idy] = Ham[idx,idy].subs(Ω2, Ω2ᶜ)

# %%
# add a detuning to the excited state
for i in range(64,67):
    Ham[i,i] += Δ

# %% [markdown]
# ### Doing the matrix calculations
# Pretty slow because of the use of symbolic matrices, but in principle only necessary once.
# First part calculates $∑_k 𝐶_𝑘 𝜌𝐶_𝑘^\dagger$

# %%
matrix_mult_sum = zeros(67,67)
for idx in tqdm(range(C_array.shape[0])):
    matrix_mult_sum[:,:] += C_array[idx]@ρ@C_conj_array[idx]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 33/33 [26:11<00:00, 47.62s/it]

# %% [markdown]
# calculating $[𝐻(𝑡),𝜌]$ and $\frac{1}{2}∑_𝑘(𝐶_𝑘  𝐶_𝑘^\dagger 𝜌+𝜌𝐶_𝑘^\dagger 𝐶_𝑘 ) $

# %%
Cprecalc = np.einsum('ijk,ikl', C_conj_array, C_array)
a = -0.5 * (Cprecalc@ρ + ρ@Cprecalc)
b = -1j*(Ham@ρ - ρ@Ham)

# %% [markdown]
# Adding them all up to get $−\frac{𝑖}{ℏ} [𝐻(𝑡),𝜌]+∑_k 𝐶_𝑘 𝜌𝐶_𝑘^\dagger-\frac{1}{2}∑_𝑘(𝐶_𝑘  𝐶_𝑘^\dagger 𝜌+𝜌𝐶_𝑘^\dagger 𝐶_𝑘 ) $

# %%
res = zeros(*ρ_ini.shape)
res += matrix_mult_sum
res += b
res += a

# %%
res[0,0]
# Out:
# 3367347.38920463*ρ₆₄,₆₄ + 3367525.85757618*ρ₆₅,₆₅ + 3367704.32982945*ρ₆₆,₆₆

# %%
res[1,25]
# Out:
# -1.0*I*(-0.0757147786543409*I*Ω1*ρ₁,₁₁*Pμ1y(t) - 0.075714778362831*Ω1*ρ₁,₁₂*Pμ1z(t) + 0.092731286369346*I*Ω1*ρ₁,₁₃*Pμ1y(t) - 0.0142467594749059*Ω1*ρ₁,₅*Pμ1z(t) - 0.0100747192556454*I*Ω1*ρ₁,₆*Pμ1y(t) - 0.427315860824937*Ω1*ρ₁,₈*Pμ1z(t) - 0.302157917858979*I*Ω1*ρ₁,₉*Pμ1y(t) - 0.0618208578761357*I*Ω2ᶜ*ρ₁,₃₆*Pμ2y(t) - 0.0618208578635748*Ω2ᶜ*ρ₁,₃₇*Pμ2z(t) + 0.075714778525579*I*Ω2ᶜ*ρ₁,₃₈*Pμ2y(t) - 0.0267693342803122*I*Ω2ᶜ*ρ₁,₄₂*Pμ2y(t) + 0.033860728157395*Ω2ᶜ*ρ₁,₄₃*Pμ2z(t) - 0.0146620825594791*I*Ω2ᶜ*ρ₁,₄₄*Pμ2y(t) + 0.36970367124329*I*Ω2ᶜ*ρ₁,₄₉*Pμ2y(t) - 0.467642269925525*Ω2ᶜ*ρ₁,₅₀*Pμ2z(t) + 0.202495045902286*I*Ω2ᶜ*ρ₁,₅₁*Pμ2y(t) + 0.43301194779964*Ωᶜ*ρ₁,₆₄*Plz(t) - 0.306186843148922*Ωᶜ*ρ₁,₆₅*Plx(t) - 83784383499.2427*ρ₁,₂₅)

# %% [markdown]
# ## Convert matrix to system of equations code
# Calculating the LHS of the Lindblad equation results in a 2D array, and here we go through the array element by element and write them out as single lines of code, i.e.:
# ```Julia
# du[1,1] = 3367347.38920463*ρ[37,37] + 3367525.85757619*ρ[38,38] + 3367704.32982946*ρ[39,39]
# ```
# Note that Julia arrays start at 1, whereas python starts at 0.

# %%
code_lines = []
for idx in tqdm(range(res.shape[0])):
    for idy in range(res.shape[0]):
        if res[idx,idy] != 0:
            cline = str(res[idx,idy])
            cline = f"du[{idx+1},{idy+1}] = " + cline
            cline = cline.replace("Plx(t)", "Plx")
            cline = cline.replace("Plz(t)", "Plz")
            cline = cline.replace("Pμ1y(t)", "Pm1y")
            cline = cline.replace("Pμ1z(t)", "Pm1z")
            cline = cline.replace("Pμ2y(t)", "Pm2y")
            cline = cline.replace("Pμ2z(t)", "Pm2z")
            cline = cline.replace("I", "1im")
            cline += '\n'
            for i in range(res.shape[0]):
                for j in range(res.shape[1]):
                    _ = str(ρ[i,j])
                    cline = cline.replace(_+"*", f"ρ[{i+1},{j+1}]*")
                    cline = cline.replace(_+" ", f"ρ[{i+1},{j+1}] ")
                    cline = cline.replace(_+"\n", f"ρ[{i+1},{j+1}]")
                    cline = cline.replace(_+")", f"ρ[{i+1},{j+1}])")
            cline = cline.strip()
            code_lines.append(cline)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 67/67 [04:56<00:00,  4.43s/it]

# %%
code_lines[:20]
# Out:
# ['du[1,1] = 3367347.38920463*ρ[65,65] + 3367525.85757618*ρ[66,66] + 3367704.32982945*ρ[67,67]',
#  'du[1,2] = -83545.9813842773*1im*ρ[1,2]',
#  'du[1,3] = -83566.3651275635*1im*ρ[1,3]',
#  'du[1,4] = -83586.7483215332*1im*ρ[1,4]',
#  'du[1,5] = -1.0*1im*(0.333333330908845*1im*Ω1ᶜ*ρ[1,17]*Pm1y - 0.471404517203288*Ω1ᶜ*ρ[1,18]*Pm1z + 0.333333330908771*1im*Ω1ᶜ*ρ[1,19]*Pm1y - 83783184618.4029*ρ[1,5])',
#  'du[1,6] = -1.0*1im*(-0.249541612125025*Ω1ᶜ*ρ[1,17]*Pm1z + 0.176452566062313*1im*Ω1ᶜ*ρ[1,18]*Pm1y + 0.40303152920221*1im*Ω1ᶜ*ρ[1,20]*Pm1y - 0.403031536879014*Ω1ᶜ*ρ[1,21]*Pm1z + 0.164536939176317*1im*Ω1ᶜ*ρ[1,22]*Pm1y + 0.0142469882105133*1im*Ω1ᶜ*ρ[1,25]*Pm1y - 0.0142467594749059*Ω1ᶜ*ρ[1,26]*Pm1z + 0.00581612180082648*1im*Ω1ᶜ*ρ[1,27]*Pm1y - 83783324359.4973*ρ[1,6])',
#  'du[1,7] = -1.0*1im*(-0.176452816031283*1im*Ω1ᶜ*ρ[1,17]*Pm1y + 0.176452816031244*1im*Ω1ᶜ*ρ[1,19]*Pm1y + 0.284986211598504*1im*Ω1ᶜ*ρ[1,21]*Pm1y - 0.465380543935125*Ω1ᶜ*ρ[1,22]*Pm1z + 0.284986223025554*1im*Ω1ᶜ*ρ[1,23]*Pm1y + 0.0100747192556454*1im*Ω1ᶜ*ρ[1,26]*Pm1y - 0.0164516834786425*Ω1ᶜ*ρ[1,27]*Pm1z + 0.0100743957604578*1im*Ω1ᶜ*ρ[1,28]*Pm1y - 83783324348.7985*ρ[1,7])',
#  'du[1,8] = -1.0*1im*(-0.176453068201556*1im*Ω1ᶜ*ρ[1,18]*Pm1y + 0.249542322257098*Ω1ᶜ*ρ[1,19]*Pm1z + 0.164536801299318*1im*Ω1ᶜ*ρ[1,22]*Pm1y - 0.403031215311011*Ω1ᶜ*ρ[1,23]*Pm1z + 0.403031223813111*1im*Ω1ᶜ*ρ[1,24]*Pm1y + 0.00581697541429349*1im*Ω1ᶜ*ρ[1,27]*Pm1y - 0.0142483929010576*Ω1ᶜ*ρ[1,28]*Pm1z + 0.0142481641915499*1im*Ω1ᶜ*ρ[1,29]*Pm1y - 83783324338.0963*ρ[1,8])',
#  'du[1,9] = -1.0*1im*(-0.145128621511445*Ω1ᶜ*ρ[1,17]*Pm1z + 0.102621432380386*1im*Ω1ᶜ*ρ[1,18]*Pm1y - 0.069020262062382*1im*Ω1ᶜ*ρ[1,20]*Pm1y + 0.0690200195385999*Ω1ᶜ*ρ[1,21]*Pm1z - 0.0281772059783355*1im*Ω1ᶜ*ρ[1,22]*Pm1y + 0.427315821093743*1im*Ω1ᶜ*ρ[1,25]*Pm1y - 0.427315860824937*Ω1ᶜ*ρ[1,26]*Pm1z + 0.174450985104918*1im*Ω1ᶜ*ρ[1,27]*Pm1y - 83784429890.3703*ρ[1,9])',
#  'du[1,10] = -1.0*1im*(-0.10262100055258*1im*Ω1ᶜ*ρ[1,17]*Pm1y + 0.102621000552557*1im*Ω1ᶜ*ρ[1,19]*Pm1y - 0.0488052210715407*1im*Ω1ᶜ*ρ[1,21]*Pm1y + 0.0796983122412093*Ω1ᶜ*ρ[1,22]*Pm1z - 0.0488048781068343*1im*Ω1ᶜ*ρ[1,23]*Pm1y + 0.302157917858979*1im*Ω1ᶜ*ρ[1,26]*Pm1y - 0.493421857321736*Ω1ᶜ*ρ[1,27]*Pm1z + 0.302157972578311*1im*Ω1ᶜ*ρ[1,28]*Pm1y - 83784429890.5489*ρ[1,10])',
#  'du[1,11] = -1.0*1im*(-0.102620568971875*1im*Ω1ᶜ*ρ[1,18]*Pm1y + 0.145127400467388*Ω1ᶜ*ρ[1,19]*Pm1z - 0.0281780110807853*1im*Ω1ᶜ*ρ[1,22]*Pm1y + 0.0690215066034534*Ω1ᶜ*ρ[1,23]*Pm1z - 0.0690212641018461*1im*Ω1ᶜ*ρ[1,24]*Pm1y + 0.174450956644206*1im*Ω1ᶜ*ρ[1,27]*Pm1y - 0.427315868495536*Ω1ᶜ*ρ[1,28]*Pm1z + 0.427315907625057*1im*Ω1ᶜ*ρ[1,29]*Pm1y - 83784429890.728*ρ[1,11])',
#  'du[1,12] = -1.0*1im*(0.0577350268605227*1im*Ω1ᶜ*ρ[1,17]*Pm1y - 0.209130867728502*Ω1ᶜ*ρ[1,20]*Pm1z + 0.10456547671845*1im*Ω1ᶜ*ρ[1,21]*Pm1y - 0.151429675810792*Ω1ᶜ*ρ[1,25]*Pm1z + 0.0757147786543409*1im*Ω1ᶜ*ρ[1,26]*Pm1y + 0.447213595498184*1im*Ω1ᶜ*ρ[1,30]*Pm1y - 0.365148371438513*Ω1ᶜ*ρ[1,31]*Pm1z + 0.115470053720788*1im*Ω1ᶜ*ρ[1,32]*Pm1y - 83784521261.0184*ρ[1,12])',
#  'du[1,13] = -1.0*1im*(0.0577350266382367*Ω1ᶜ*ρ[1,17]*Pm1z + 0.0408248288341134*1im*Ω1ᶜ*ρ[1,18]*Pm1y - 0.104565433461663*1im*Ω1ᶜ*ρ[1,20]*Pm1y - 0.104565476315862*Ω1ᶜ*ρ[1,21]*Pm1z + 0.128066083419699*1im*Ω1ᶜ*ρ[1,22]*Pm1y - 0.0757148376138858*1im*Ω1ᶜ*ρ[1,25]*Pm1y - 0.075714778362831*Ω1ᶜ*ρ[1,26]*Pm1z + 0.0927312135102562*1im*Ω1ᶜ*ρ[1,27]*Pm1y + 0.365148370032653*1im*Ω1ᶜ*ρ[1,31]*Pm1y - 0.461880213104865*Ω1ᶜ*ρ[1,32]*Pm1z + 0.199999998979528*1im*Ω1ᶜ*ρ[1,33]*Pm1y - 83784521250.7175*ρ[1,13])',
#  'du[1,14] = -1.0*1im*(0.0235702258946777*1im*Ω1ᶜ*ρ[1,17]*Pm1y + 0.0666666662344155*Ω1ᶜ*ρ[1,18]*Pm1z + 0.0235702258946725*1im*Ω1ᶜ*ρ[1,19]*Pm1y - 0.128066030678012*1im*Ω1ᶜ*ρ[1,21]*Pm1y + 0.128066135928642*1im*Ω1ᶜ*ρ[1,23]*Pm1y - 0.092731286369346*1im*Ω1ᶜ*ρ[1,26]*Pm1y + 0.0927311408007104*1im*Ω1ᶜ*ρ[1,28]*Pm1y + 0.282842710735502*1im*Ω1ᶜ*ρ[1,32]*Pm1y - 0.489897945427891*Ω1ᶜ*ρ[1,33]*Pm1z + 0.282842710703535*1im*Ω1ᶜ*ρ[1,34]*Pm1y - 83784521240.416*ρ[1,14])',
#  'du[1,15] = -1.0*1im*(0.040824828834037*1im*Ω1ᶜ*ρ[1,18]*Pm1y + 0.0577350266381159*Ω1ᶜ*ρ[1,19]*Pm1z - 0.12806608341946*1im*Ω1ᶜ*ρ[1,22]*Pm1y + 0.104565562252445*Ω1ᶜ*ρ[1,23]*Pm1z + 0.104565605340398*1im*Ω1ᶜ*ρ[1,24]*Pm1y - 0.0927312135100828*1im*Ω1ᶜ*ρ[1,27]*Pm1y + 0.075714659506396*Ω1ᶜ*ρ[1,28]*Pm1z + 0.0757146001617907*1im*Ω1ᶜ*ρ[1,29]*Pm1y + 0.199999998979154*1im*Ω1ᶜ*ρ[1,33]*Pm1y - 0.461880213051799*Ω1ᶜ*ρ[1,34]*Pm1z + 0.365148370031906*1im*Ω1ᶜ*ρ[1,35]*Pm1y - 83784521230.1141*ρ[1,15])',
#  'du[1,16] = -1.0*1im*(0.0577350268605541*1im*Ω1ᶜ*ρ[1,19]*Pm1y - 0.104565562655309*1im*Ω1ᶜ*ρ[1,23]*Pm1y + 0.209131211486524*Ω1ᶜ*ρ[1,24]*Pm1z - 0.0757146597981051*1im*Ω1ᶜ*ρ[1,28]*Pm1y + 0.151429200906999*Ω1ᶜ*ρ[1,29]*Pm1z + 0.115470053707826*1im*Ω1ᶜ*ρ[1,34]*Pm1y - 0.365148371438729*Ω1ᶜ*ρ[1,35]*Pm1z + 0.447213595499958*1im*Ω1ᶜ*ρ[1,36]*Pm1y - 83784521219.8117*ρ[1,16])',
#  'du[1,17] = -1.0*1im*(-0.0577350268605227*1im*Ω1*ρ[1,12]*Pm1y + 0.0577350266382367*Ω1*ρ[1,13]*Pm1z - 0.0235702258946777*1im*Ω1*ρ[1,14]*Pm1y - 0.333333330908845*1im*Ω1*ρ[1,5]*Pm1y - 0.249541612125025*Ω1*ρ[1,6]*Pm1z + 0.176452816031283*1im*Ω1*ρ[1,7]*Pm1y - 0.145128621511445*Ω1*ρ[1,9]*Pm1z + 0.10262100055258*1im*Ω1*ρ[1,10]*Pm1y + 0.424264068139511*1im*Ω2ᶜ*ρ[1,37]*Pμ2y(t) - 0.424264068053308*Ω2ᶜ*ρ[1,38]*Pμ2z(t) + 0.173205080287012*1im*Ω2ᶜ*ρ[1,39]*Pμ2y(t) - 0.284538010900662*Ωᶜ*ρ[1,65]*Plz - 0.201189869144348*Ωᶜ*ρ[1,66]*Plx - 83782268394.2963*ρ[1,17])',
#  'du[1,18] = -1.0*1im*(0.102620568971875*1im*Ω1*ρ[1,11]*Pm1y - 0.0408248288341134*1im*Ω1*ρ[1,13]*Pm1y + 0.0666666662344155*Ω1*ρ[1,14]*Pm1z - 0.040824828834037*1im*Ω1*ρ[1,15]*Pm1y - 0.471404517203288*Ω1*ρ[1,5]*Pm1z - 0.176452566062313*1im*Ω1*ρ[1,6]*Pm1y + 0.176453068201556*1im*Ω1*ρ[1,8]*Pm1y - 0.102621432380386*1im*Ω1*ρ[1,9]*Pm1y + 0.299999999433098*1im*Ω2ᶜ*ρ[1,38]*Pμ2y(t) - 0.48989794706239*Ω2ᶜ*ρ[1,39]*Pμ2z(t) + 0.299999999153891*1im*Ω2ᶜ*ρ[1,40]*Pμ2y(t) - 0.201197275757057*Ωᶜ*ρ[1,65]*Plx - 0.201191350267514*Ωᶜ*ρ[1,67]*Plx - 83782268404.3226*ρ[1,18])',
#  'du[1,19] = -1.0*1im*(0.145127400467388*Ω1*ρ[1,11]*Pm1z - 0.0235702258946725*1im*Ω1*ρ[1,14]*Pm1y + 0.0577350266381159*Ω1*ρ[1,15]*Pm1z - 0.0577350268605541*1im*Ω1*ρ[1,16]*Pm1y - 0.333333330908771*1im*Ω1*ρ[1,5]*Pm1y - 0.176452816031244*1im*Ω1*ρ[1,7]*Pm1y + 0.249542322257098*Ω1*ρ[1,8]*Pm1z - 0.102621000552557*1im*Ω1*ρ[1,10]*Pm1y + 0.173205080286974*1im*Ω2ᶜ*ρ[1,39]*Pμ2y(t) - 0.424264067658355*Ω2ᶜ*ρ[1,40]*Pμ2z(t) + 0.424264068056331*1im*Ω2ᶜ*ρ[1,41]*Pμ2y(t) - 0.201198757413415*Ωᶜ*ρ[1,66]*Plx + 0.284525441009039*Ωᶜ*ρ[1,67]*Plz - 83782268414.3498*ρ[1,19])',
#  'du[1,20] = -1.0*1im*(-0.209130867728502*Ω1*ρ[1,12]*Pm1z + 0.104565433461663*1im*Ω1*ρ[1,13]*Pm1y - 0.40303152920221*1im*Ω1*ρ[1,6]*Pm1y + 0.069020262062382*1im*Ω1*ρ[1,9]*Pm1y - 0.170754638409227*Ω2ᶜ*ρ[1,37]*Pμ2z(t) + 0.0853773191872665*1im*Ω2ᶜ*ρ[1,38]*Pμ2y(t) + 0.445659811465872*1im*Ω2ᶜ*ρ[1,42]*Pμ2y(t) - 0.363879713655668*Ω2ᶜ*ρ[1,43]*Pμ2z(t) + 0.11506886926103*1im*Ω2ᶜ*ρ[1,44]*Pμ2y(t) + 0.00729016904451585*1im*Ω2ᶜ*ρ[1,49]*Pμ2y(t) - 0.00595232115186635*Ω2ᶜ*ρ[1,50]*Pμ2z(t) + 0.00188226486732114*1im*Ω2ᶜ*ρ[1,51]*Pμ2y(t) - 0.112244204820295*Ωᶜ*ρ[1,65]*Plx - 83782548132.8854*ρ[1,20])']

# %% [markdown]
# # Solving ODE system with Julia
# Need to install Julia and add the following packages to Julia:
# * [Waveforms](https://github.com/Paalon/Waveforms.jl) $\rightarrow$ used for a square wave function
# * [DifferentialEquations](https://diffeq.sciml.ai/stable/)
# * [BenchmarkTools](https://github.com/JuliaCI/BenchmarkTools.jl)
#
# And install [PyJulia](https://pyjulia.readthedocs.io/en/latest/index.html) for python.

# %%
from julia import Main

# %%
Main.eval("""using Waveforms""")
Main.eval("""using DifferentialEquations""")
Main.eval("""using BenchmarkTools""")

# %% [markdown]
# ## Define Square Wave in Jullia

# %%
Main.eval("""
function square_wave(t::Float64, frequency::Float64, phase::Float64)
    0.5.*(1 .+ squarewave(2*pi.*frequency.*t .+ phase))
end
""")
# Out:
# <PyCall.jlwrap square_wave>

# %% [markdown]
# ## Creating the Julia function to compute the RHS of the Lindblad Equation
# Note that only here the polarization switching function is added.
# Anything added symbolically can be modified here.

# %%
ode_fun = """
function Lindblad_rhs!(du, ρ, p, t)
\t@inbounds begin
\t\tΩ = p[1]
\t\tΩᶜ = conj(Ω)
\t\tνp = p[2]
\t\tΩ1 = p[3]
\t\tΩ1ᶜ = conj(Ω1)
\t\tνp1 = p[4]
\t\tΩ2 = p[5]
\t\tνp2 = p[6]
\t\tΩ2ᶜ = conj(Ω2)
\t\tΔ = p[7]
\t\tPlx = square_wave(t, νp, 3.141592653589793)
\t\tPlz = square_wave(t, νp, 0.0)    
\t\tPm1y = square_wave(t, νp1, 1.0471975511965976)
\t\tPm1z = square_wave(t, νp1, 4.1887902047863905)
\t\tPm2y = square_wave(t, νp2, 2.0943951023931953)
\t\tPm2z = square_wave(t, νp2, 5.235987755982988)
"""

# %%
print(ode_fun)
# Out:
# function Lindblad_rhs!(du, ρ, p, t)
# 	@inbounds begin
# 		Ω = p[1]
# 		Ωᶜ = conj(Ω)
# 		νp = p[2]
# 		Ω1 = p[3]
# 		Ω1ᶜ = conj(Ω1)
# 		νp1 = p[4]
# 		Ω2 = p[5]
# 		νp2 = p[6]
# 		Ω2ᶜ = conj(Ω2)
# 		Δ = p[7]
# 		Plx = square_wave(t, νp, 3.141592653589793)
# 		Plz = square_wave(t, νp, 0.0)
# 		Pm1y = square_wave(t, νp1, 1.0471975511965976)
# 		Pm1z = square_wave(t, νp1, 4.1887902047863905)
# 		Pm2y = square_wave(t, νp2, 2.0943951023931953)
# 		Pm2z = square_wave(t, νp2, 5.235987755982988)

# %%
for cline in code_lines:
    ode_fun += "\t\t"+cline+'\n'
ode_fun += '\t end \n \t nothing \n end'

# %%
with open('ode_fun_mu1mu2.jl', 'w', encoding='utf8') as f:
    f.write(ode_fun)

# %%
# reading from file
with open('ode_fun_mu1mu2.jl', 'r', encoding='utf8') as f:
    ode_fun = f.read()

# %%
# make function smaller for testing purposes
# ode_fun = '\n'.join(ode_fun.split('\n')[1:50])
# ode_fun += '\n \t end \n \t nothing \n end'

# %% [markdown]
# This creates a Julia function

# %%
# making the function in Julia
Main.eval(ode_fun)
# Out:
# <PyCall.jlwrap Lindblad_rhs!>

# %% [markdown]
# Setup the variables needed in Julia by sending them from python to Julia

# %%
Γ = 1/(100e-9)
Ω =  Γ
ωp = Γ
νp = ωp/(2*np.pi)
νp1 = νp
Ω1 = Γ
νp2 = νp
Ω2 = Γ
Δ = 0

Main.Ω = Ω
Main.νp = νp
Main.Ω1 = Ω1
Main.νp1 = νp1
Main.Ω2 = Ω2
Main.νp2 = νp2
Main.Δ = Δ
Main.Γ = Γ

Main.ρ_ini = ρ_ini

# setting up the parameters to send to the differential equation
Main.eval("p = [Ω, νp, Ω1, νp1, Ω2, νp2, Δ]")
# Out:
# array([10000000.        ,  1591549.43091895, 10000000.        ,
#         1591549.43091895, 10000000.        ,  1591549.43091895,
#               0.        ])

# %%
# %%time
du = np.zeros(ρ_ini.shape, dtype = 'complex')
Main.du = du
Main.eval("""
@time Lindblad_rhs!(du, ρ_ini, [Ω, νp, Ω1, νp1, Ω2, νp1, Δ], 0.)
tmp = 0
""")
# Out:
# Wall time: 15min 13s
# 0

# %%
# %%time
du = np.zeros(ρ_ini.shape, dtype = 'complex')
Main.du = du
Main.eval("""
@time Lindblad_rhs!(du, ρ_ini, [Ω, νp, Ω1, νp1, Ω2, νp1, Δ], 0.)
tmp = 0
""")
# Out:
# Wall time: 71.1 ms
# 0

# %% [markdown]
# ### Setting up the ODE problem to solve
# `tmp = 0` is just to prevent `Main.eval` from outputting the problem in the notebook.
# The ODEProblem takes a function to solve (`Lindblad_rhs!` in this case), initial conditions `ρ_ini`, a timespan `tspan` an additional arguments for the ODE function, denoted here by `p`

# %%
Main.eval("""
tspan = (0.0f0, 100e-6)
prob = ODEProblem(Lindblad_rhs!,ρ_ini,tspan,p)
tmp = 0
""")
# Out:
# 0

# %% [markdown]
# The ODEProblem is then solved with the `solve` function, which takes as inputs the ODEProblem `prob`, the method (`Tsit5()` in this case, a RK45 like method), tolerances and many more parameters (more detail [here](https://diffeq.sciml.ai/stable/basics/common_solver_opts/)).
# Julia has a JIT compiler, so the first run compiles the code, which means it takes a bit longer. Any subsequent runs (even with changing parameters) will run much faster, provided the type of the parameters doesn't change. Changing the type changes the function signature and requires recompilation.

# %%
# %%time
Main.eval("""
@time sol = solve(prob, Tsit5(), abstol = 2.5e-7, reltol = 2.4e-4)
tmp = 0
""")
# Out:
# Wall time: 4.17 s
# 0

# %% [markdown]
# @time prints the actual runtime in Julia into the terminal (8.54 s)
# ### Second run; code already compiled

# %%
# %%time
Main.eval("""
@time sol = solve(prob, Tsit5(), abstol = 2.5e-7, reltol = 2.4e-4)
tmp = 0
""")
# Out:
# Wall time: 4.34 s
# 0

# %% [markdown]
# after compilation it runs in 4.4 s. This may not seem that much faster than python (11 vs 4.4 s), but remember that whereas python uses multiple cores for array operations, this only uses a single core. We can get another massive speedup by utilizing multiple cores for solving the same system for different initial conditions or parameters.

# %%
ut = np.array(Main.eval("sol[:]")).T
pop_results = np.real(np.einsum('jji->ji',ut.reshape((ρ_ini.shape[0], ρ_ini.shape[1], ut.shape[2]))))
t_array = Main.eval("""sol.t""")


#Plot populations in different J
P0_triplet = np.sum(pop_results[1:4,:], axis = 0)
P0_singlet = np.sum(pop_results[0:1,:], axis = 0)
P0 = np.sum(pop_results[:4], axis = 0)
P1 = np.sum(pop_results[4:16,:], axis = 0)
P2 = np.sum(pop_results[16:36,:], axis = 0)
P3 = np.sum(pop_results[36:64,:], axis = 0)
PB1 = np.sum(pop_results[64:,:], axis = 0)

print(P0[-1]/np.diag(ρ_ini)[:4].sum().real)

fig, ax = plt.subplots(figsize = (12,8))
# ax.plot(t_array*1e6, P0_triplet, label = 'X, J = 0, F = 1')
# ax.plot(t_array*1e6, P0_singlet, label = 'X, J = 0, F = 0')
ax.plot(t_array*1e6, P0, label = 'X, J = 0')
ax.plot(t_array*1e6, P1, label = 'X, J = 1')
ax.plot(t_array*1e6, P2, label = 'X, J = 2')
ax.plot(t_array*1e6, PB1, label = 'B, J = 1')
ax.legend(fontsize = 14)
ax.set_xlabel("Time [us]", fontsize = 14)
ax.set_ylabel("Population in state", fontsize = 14)
ax.tick_params(axis='both', labelsize=14)
ax.grid(True)


m = t_array <= 5e6/(νp)/1e6

t_array = t_array[m]
pop_results = pop_results[:,m]
P0_triplet = np.sum(pop_results[1:4,:], axis = 0)
P0_singlet = np.sum(pop_results[0:1,:], axis = 0)
P0 = np.sum(pop_results[:4], axis = 0)
P1 = np.sum(pop_results[4:16,:], axis = 0)
P2 = np.sum(pop_results[16:36,:], axis = 0)
PB1 = np.sum(pop_results[36:,:], axis = 0)

fig, ax = plt.subplots(figsize = (12,8))
ax.plot(t_array*1e6, P0, label = 'X, J = 0')
ax.plot(t_array*1e6, P2, label = 'X, J = 2')
ax.plot(t_array*1e6, PB1, label = 'B, J = 1 ')
ax.legend(fontsize = 14)
ax.set_xlabel("Time [us]", fontsize = 14)
ax.set_ylabel("Population in state", fontsize = 14)
ax.tick_params(axis='both', labelsize=14)
for i in range(10):
    ax.axvline(i*1e6/νp/2, zorder = 0, color = 'k')
# Out:
# 15.461779408913467

# %% [markdown]
# ## Effect of tolerances
#
# Varying the tolerances to see what effect it has on the runtime and the final result.

# %%
abstolerances = np.logspace(-6,-9,7)
reltolerances = np.logspace(-3,-6,7)

# %%
import time

elapsed_times = []
time_arrays = []
solutions = []
for abstol, reltol in tqdm(zip(abstolerances, reltolerances), total=len(abstolerances)):
    # compile function before timing
    dt = []
    Main.eval(f"""
    sol = solve(prob, Tsit5(), abstol = {abstol}, reltol = {reltol})
    tmp = 0
    """)
    Main.eval(f'println({abstol}, ", ",{reltol})')
    for _ in range(3):
        tstart = time.time()
        Main.eval(f"""
        @time sol = solve(prob, Tsit5(), abstol = {abstol}, reltol = {reltol})
        tmp = 0
        """)
        tstop = time.time()
        dt.append(tstop - tstart)
    elapsed_times.append(np.mean(dt))
    ut = np.array(Main.eval("sol[:]")).T
    pop_results = np.real(np.einsum('jji->ji',ut.reshape((ρ_ini.shape[0], ρ_ini.shape[1], ut.shape[2]))))
    solutions.append(pop_results)
    time_arrays.append(np.array(Main.eval("sol.t")))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 7/7 [12:13<00:00, 104.85s/it]

# %%
fig, axes = plt.subplots(2,figsize = (10,12), sharex = True, 
                         gridspec_kw = {'hspace': 0})

ax = axes[0]
ax.grid(True, which = 'both')

ax.plot(abstolerances*1e6, elapsed_times, '--.', ms = 14)

ax.set_xscale('log')
ax.set_ylabel('elapsed time', fontsize = 14)
ax.tick_params(axis='both', labelsize=14)

ax = axes[1]
ax.grid(True, which = 'both')

factors = []
for sol, factor in zip(solutions, abstolerances*1e6):
    P0 = np.sum(sol[:4,:], axis = 0)
    factors.append(P0[-1]/P0[0])
    
ax.plot(abstolerances*1e6, factors, '--.', ms = 14, color = 'C0')

ax.set_xscale('log')
ax.invert_xaxis()
ax.set_xlabel('x [default tolerance]', fontsize = 14)
ax.set_ylabel('population ratio', fontsize = 14)
ax.tick_params(axis='both', labelsize=14)

# %%
fig, ax = plt.subplots(figsize = (10,6))

for ti, sol, factor in zip(time_arrays, solutions, abstolerances*1e6):
    P0 = np.sum(sol[:4,:], axis = 0)
    P1 = np.sum(sol[4:16,:], axis = 0)
    P2 = np.sum(sol[16:36,:], axis = 0)
    PB1 = np.sum(sol[36:,:], axis = 0)
    
    ax.plot(ti*1e6, PB1, label = f'B, $J=1$; tol x {factor:.1e}')
    
ax.legend(fontsize = 14)
ax.set_xlabel('time [μs]', fontsize = 14)
ax.set_ylabel('population', fontsize = 14)
ax.tick_params(axis='both', labelsize=14)

ax.set_xlim(0,5e6/νp)
for i in range(20):
    ax.axvline(i*1e6/νp/2, zorder = 0, color = 'k')

# %% [markdown]
# ### Comparison with Python solution
#
# Check the timing differences. Remember that the first run compiles the Julia code, and subsequent runs (even when changing parameters or initial conditions) are much faster.

# %%
# %%time
sol = solve_ivp(Lindblad_rhs, t_span, ρ_vec, method = 'RK45', dense_output=False, 
                vectorized = False, args = [p], rtol = 2.5e-4, atol = 2.5e-7)
# Out:
# Wall time: 13 s

# %%
# %%time
Main.eval("""
@time sol = solve(prob, Tsit5(), abstol = 2.5e-7, reltol = 2.4e-4)
tmp = 0
""")
# Out:
# Wall time: 37 s
# 0

# %%
# %%time
Main.eval("""
@time sol = solve(prob, Tsit5(), abstol = 2.5e-7, reltol = 2.4e-4)
tmp = 0
""")
# Out:
# Wall time: 23.4 s
# 0

# %%
pop_results_scipy = np.real(np.einsum('jji->ji',sol.y.reshape((ρ_ini.shape[0], ρ_ini.shape[1], sol.y.shape[1]))))

_u = np.array(Main.eval("sol.u")).T
pop_results_julia = np.real(np.einsum('jji->ji',_u.reshape((ρ_ini.shape[0], ρ_ini.shape[1], _u.shape[2]))))

tmin = 0
tmax = 101e-6
m1 = (tmin < sol.t) & (sol.t < tmax)
m2 = (tmin < Main.eval('sol.t')) & (Main.eval('sol.t') < tmax)

fig, ax = plt.subplots(figsize = (10,6))
ax.plot(sol.t[m1]*1e6, np.sum(pop_results_scipy[:4], axis = 0)[m1], label = r'X, $J=0$; python')
ax.plot(Main.eval("sol.t")[m2]*1e6, np.sum(pop_results_julia[:4], axis = 0)[m2], label = r'X, $J=0$; julia')

ax.legend(fontsize = 14)
ax.set_xlabel('time [μs]')
ax.set_ylabel('population')
set_fontsize(ax, 14)

# %%
pop_results_scipy = np.real(np.einsum('jji->ji',sol.y.reshape((ρ_ini.shape[0], ρ_ini.shape[1], sol.y.shape[1]))))

_u = np.array(Main.eval("sol.u")).T
pop_results_julia = np.real(np.einsum('jji->ji',_u.reshape((ρ_ini.shape[0], ρ_ini.shape[1], _u.shape[2]))))

tmin = 0
tmax = 2e-6
m1 = (tmin < sol.t) & (sol.t < tmax)
m2 = (tmin < Main.eval('sol.t')) & (Main.eval('sol.t') < tmax)

fig, ax = plt.subplots(figsize = (10,6))
ax.plot(sol.t[m1]*1e6, np.sum(pop_results_scipy[:4], axis = 0)[m1], label = r'X, $J=0$; python')
ax.plot(Main.eval("sol.t")[m2]*1e6, np.sum(pop_results_julia[:4], axis = 0)[m2], label = r'X, $J=0$; julia')

ax.legend(fontsize = 14)
ax.set_xlabel('time [μs]')
ax.set_ylabel('population')
set_fontsize(ax, 14)

# %%
pop_results_scipy = np.real(np.einsum('jji->ji',sol.y.reshape((ρ_ini.shape[0], ρ_ini.shape[1], sol.y.shape[1]))))

_u = np.array(Main.eval("sol.u")).T
pop_results_julia = np.real(np.einsum('jji->ji',_u.reshape((ρ_ini.shape[0], ρ_ini.shape[1], _u.shape[2]))))

tmin = 0
tmax = 5e-6
m1 = (tmin < sol.t) & (sol.t < tmax)
m2 = (tmin < Main.eval('sol.t')) & (Main.eval('sol.t') < tmax)

fig, ax = plt.subplots(figsize = (10,6))
ax.plot(sol.t[m1]*1e6, np.sum(pop_results_scipy[-3:], axis = 0)[m1], label = r'B, $J=1$; python')
ax.plot(Main.eval("sol.t")[m2]*1e6, np.sum(pop_results_julia[-3:,:], axis = 0)[m2], label = r'B, $J=1$; julia')

ax.legend(fontsize = 14)
ax.set_xlabel('time [μs]')
ax.set_ylabel('population')
set_fontsize(ax, 14)

# %% [markdown]
# ## Check simulation without microwaves

# %%
Γ = 1/(100e-9)
Ω =  Γ
ωp = Γ
νp = ωp/(2*np.pi)
νp1 = 0
Ω1 = 0
νp2 = 0
Ω2 = 0
Δ = 0

Main.Ω = Ω
Main.νp = νp
Main.Ω1 = Ω1
Main.νp1 = νp1
Main.Ω2 = Ω2
Main.νp2 = νp2
Main.Δ = Δ
Main.Γ = Γ

Main.ρ_ini = ρ_ini

# setting up the parameters to send to the differential equation
Main.eval("p = [Ω, νp, Ω1, νp1, Ω2, νp2, Δ]")
# Out:
# array([10000000.        ,  1591549.43091895,        0.        ,
#               0.        ,        0.        ,        0.        ,
#               0.        ])

# %%
Main.eval("""
tspan = (0.0f0, 100e-6)
prob = ODEProblem(Lindblad_rhs!,ρ_ini,tspan,p)
tmp = 0
""")
# Out:
# 0

# %%
# %%time
Main.eval("""
@time sol = solve(prob, Tsit5(), abstol = 2.5e-7, reltol = 2.4e-4)
tmp = 0
""")
# Out:
# Wall time: 1.65 s
# 0

# %%
ut = np.array(Main.eval("sol[:]")).T
pop_results = np.real(np.einsum('jji->ji',ut.reshape((ρ_ini.shape[0], ρ_ini.shape[1], ut.shape[2]))))
t_array = Main.eval("""sol.t""")


#Plot populations in different J
P0_triplet = np.sum(pop_results[1:4,:], axis = 0)
P0_singlet = np.sum(pop_results[0:1,:], axis = 0)
P0 = np.sum(pop_results[:4], axis = 0)
P1 = np.sum(pop_results[4:16,:], axis = 0)
P2 = np.sum(pop_results[16:36,:], axis = 0)
P3 = np.sum(pop_results[36:64,:], axis = 0)
PB1 = np.sum(pop_results[64:,:], axis = 0)

print(P0[-1]/np.diag(ρ_ini)[:4].sum().real)

fig, ax = plt.subplots(figsize = (12,8))
# ax.plot(t_array*1e6, P0_triplet, label = 'X, J = 0, F = 1')
# ax.plot(t_array*1e6, P0_singlet, label = 'X, J = 0, F = 0')
ax.plot(t_array*1e6, P0, label = 'X, J = 0')
ax.plot(t_array*1e6, P1, label = 'X, J = 1')
ax.plot(t_array*1e6, P2, label = 'X, J = 2')
ax.plot(t_array*1e6, PB1, label = 'B, J = 1')
ax.legend(fontsize = 14)
ax.set_xlabel("Time [us]", fontsize = 14)
ax.set_ylabel("Population in state", fontsize = 14)
ax.tick_params(axis='both', labelsize=14)
ax.grid(True)


m = t_array <= 5e6/(νp)/1e6

t_array = t_array[m]
pop_results = pop_results[:,m]
P0_triplet = np.sum(pop_results[1:4,:], axis = 0)
P0_singlet = np.sum(pop_results[0:1,:], axis = 0)
P0 = np.sum(pop_results[:4], axis = 0)
P1 = np.sum(pop_results[4:16,:], axis = 0)
P2 = np.sum(pop_results[16:36,:], axis = 0)
PB1 = np.sum(pop_results[36:,:], axis = 0)

fig, ax = plt.subplots(figsize = (12,8))
ax.plot(t_array*1e6, P0, label = 'X, J = 0')
ax.plot(t_array*1e6, P2, label = 'X, J = 2')
ax.plot(t_array*1e6, PB1, label = 'B, J = 1 ')
ax.legend(fontsize = 14)
ax.set_xlabel("Time [us]", fontsize = 14)
ax.set_ylabel("Population in state", fontsize = 14)
ax.tick_params(axis='both', labelsize=14)
for i in range(10):
    ax.axvline(i*1e6/νp/2, zorder = 0, color = 'k')
# Out:
# 4.213692176388502
